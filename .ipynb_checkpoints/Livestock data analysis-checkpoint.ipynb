# %% [markdown]
# ### Importing all the required packages and libraries

# %%
#Data Manipulation
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
from sklearn.linear_model import LinearRegression
#from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### Importing csv datasets and converting into dataframes

# %%
livestockPopn = pd.read_csv("/Users/saramshkhadka/Downloads/Thesis/Livestock data analysis/1 Livestock population.csv")
milkAnimal = pd.read_csv("/Users/saramshkhadka/Downloads/Thesis/Livestock data analysis/2 Milking animals.csv")
meatProd = pd.read_csv("/Users/saramshkhadka/Downloads/Thesis/Livestock data analysis/3 Meat production.csv")
eggProd = pd.read_csv("/Users/saramshkhadka/Downloads/Thesis/Livestock data analysis/4 Egg production.csv")
woolProd = pd.read_csv("/Users/saramshkhadka/Downloads/Thesis/Livestock data analysis/5 Wool production.csv")
yakPopn = pd.read_csv("/Users/saramshkhadka/Downloads/Thesis/Livestock data analysis/6 YakNakChauri population.csv")
rabbitPopn = pd.read_csv("/Users/saramshkhadka/Downloads/Thesis/Livestock data analysis/7 Rabbit population.csv")
horsesPopn = pd.read_csv("/Users/saramshkhadka/Downloads/Thesis/Livestock data analysis/8 HorsesAsses population.csv")

# %% [markdown]
# ### Understanding each datasets

# %% [markdown]
# ### Livestock population

# %%
#viewing first five data
livestockPopn.head()
# Out:
#   Province  District  Cattle  Buffaloes  Sheep    Goat   Pigs     Fowl  Duck
# 0        1   BHOJPUR   92751      54766   6050  101628  48318   322655  1825
# 1        1  DHANKUTA   95805      19354    542  187016  32654   588912  3949
# 2        1      ILAM  161288      23840    138  169842  31762   525401   968
# 3        1     JHAPA  273501      78000     38  320000  74000  1430000  5150
# 4        1   KHOTANG   95898      63064   6163  135082  48826   363494  2230

# %%
#returns the row and column count of a dataset
livestockPopn.shape
# Out:
# (77, 9)

# %%
#verify data quality and check missing values
livestockPopn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Province   77 non-null     object
#  1   District   77 non-null     object
#  2   Cattle     77 non-null     int64
#  3   Buffaloes  77 non-null     int64
#  4   Sheep      77 non-null     int64
#  5   Goat       77 non-null     int64
#  6   Pigs       77 non-null     int64
#  7   Fowl       77 non-null     int64
#  8   Duck       77 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 5.5+ KB

# %%
#provide basis stastics attributes
livestockPopn.describe()
# Out:
#               Cattle      Buffaloes         Sheep           Goat  \
# count      77.000000      77.000000     77.000000      77.000000
# mean    96971.961039   67012.090909  10308.116883  174579.402597
# std     75217.328278   47041.149406  12765.496684   93734.544508
# min      2308.000000       0.000000      0.000000    5879.000000
# 25%     43989.000000   30966.000000   1242.000000  101628.000000
# 50%     81710.000000   56839.000000   5258.000000  148835.000000
# 75%    129857.000000   96636.000000  14273.000000  249358.000000
# max    432314.000000  197380.000000  73241.000000  387376.000000
#
#                Pigs          Fowl          Duck
# count     77.000000  7.700000e+01     77.000000
# mean   20634.259740  9.534815e+05   5613.324675
# std    20765.919009  2.209782e+06   8884.759961
# min       32.000000  7.105000e+03      0.000000
# 25%     6849.000000  2.286340e+05    590.000000
# 50%    12556.000000  4.807950e+05   2038.000000
# 75%    28493.000000  9.489720e+05   7179.000000
# max    92161.000000  1.887563e+07  56097.000000

# %%
#find the duplicates
livestockPopn.duplicated().sum()
# Out:
# 0

# %%
#find the null values
livestockPopn.isnull().sum()
# Out:
# Province     0
# District     0
# Cattle       0
# Buffaloes    0
# Sheep        0
# Goat         0
# Pigs         0
# Fowl         0
# Duck         0
# dtype: int64

# %% [markdown]
# ### Milk animal

# %%
#viewing first five data
milkAnimal.head()
# Out:
#   Province  District  Milking Cows No.  Milking Buffaloes No.  Cow Milk  \
# 0        1   BHOJPUR             15026                  17251      8373
# 1        1  DHANKUTA             15273                   5922     10040
# 2        1      ILAM             24032                   7577     26292
# 3        1     JHAPA             54000                  26610     58345
# 4        1   KHOTANG             13809                  17280      7623
#
#    Buffaloes Milk  Total Milk Produced
# 0            9686                18059
# 1            3946                13986
# 2            5927                32219
# 3           23339                81684
# 4            9975                17598

# %%
#returns the row and column count of a dataset
milkAnimal.shape
# Out:
# (77, 7)

# %%
#verify data quality and check missing values
milkAnimal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Province               77 non-null     object
#  1   District               77 non-null     object
#  2   Milking Cows No.       77 non-null     int64
#  3   Milking Buffaloes No.  77 non-null     int64
#  4   Cow Milk               77 non-null     int64
#  5   Buffaloes Milk         77 non-null     int64
#  6   Total Milk Produced    77 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 4.3+ KB

# %%
#provide basis stastics attributes
milkAnimal.describe()
# Out:
#        Milking Cows No.  Milking Buffaloes No.      Cow Milk  Buffaloes Milk  \
# count         77.000000              77.000000     77.000000       77.000000
# mean       15701.831169           21177.168831  13772.571429    18433.896104
# std        12732.271261           15483.435018  14183.900524    14660.520758
# min          369.000000               0.000000    165.000000        0.000000
# 25%         7292.000000            8995.000000   4632.000000     6388.000000
# 50%        13190.000000           18550.000000   9453.000000    15645.000000
# 75%        20467.000000           28176.000000  18707.000000    25289.000000
# max        75250.000000           62321.000000  83410.000000    59333.000000
#
#        Total Milk Produced
# count            77.000000
# mean          32206.506494
# std           26222.038857
# min             165.000000
# 25%           13255.000000
# 50%           25945.000000
# 75%           41748.000000
# max          115697.000000

# %%
#find the duplicates
milkAnimal.duplicated().sum()
# Out:
# 0

# %%
#find the null values
milkAnimal.isnull().sum()
# Out:
# Province                 0
# District                 0
# Milking Cows No.         0
# Milking Buffaloes No.    0
# Cow Milk                 0
# Buffaloes Milk           0
# Total Milk Produced      0
# dtype: int64

# %% [markdown]
# ### Meat production

# %%
#viewing first five data
meatProd.head()
# Out:
#   Province  District  Buff  Mutton  Chevon  Pork  Chicken  Duck  Total Meat
# 0        1   BHOJPUR  1923      23     535   956     1095     2        4534
# 1        1  DHANKUTA   680       2     984   646     1956     4        4273
# 2        1      ILAM   837       1     894   629     1634     1        3996
# 3        1     JHAPA  2739       0    1684  1465     4308     5       10202
# 4        1   KHOTANG  2215      23     711   966     1195     2        5113

# %%
#returns the row and column count of a dataset
meatProd.shape
# Out:
# (77, 9)

# %%
#verify data quality and check missing values
meatProd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Province    77 non-null     object
#  1   District    77 non-null     object
#  2   Buff        77 non-null     int64
#  3   Mutton      77 non-null     int64
#  4   Chevon      77 non-null     int64
#  5   Pork        77 non-null     int64
#  6   Chicken     77 non-null     int64
#  7   Duck        77 non-null     int64
#  8   Total Meat  77 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 5.5+ KB

# %%
#provide basis stastics attributes
meatProd.describe()
# Out:
#               Buff      Mutton       Chevon         Pork       Chicken  \
# count    77.000000   77.000000    77.000000    77.000000     77.000000
# mean   2443.805195   38.519481   918.883117   408.454545   2947.558442
# std    1706.259205   47.601584   493.312674   411.005012   6642.757579
# min       0.000000    0.000000    31.000000     1.000000     24.000000
# 25%    1155.000000    5.000000   535.000000   136.000000    753.000000
# 50%    2092.000000   20.000000   783.000000   249.000000   1514.000000
# 75%    3302.000000   53.000000  1312.000000   564.000000   3003.000000
# max    6981.000000  273.000000  2039.000000  1824.000000  56720.000000
#
#             Duck    Total Meat
# count  77.000000     77.000000
# mean    5.701299   6762.870130
# std     9.806100   7474.056519
# min     0.000000     69.000000
# 25%     1.000000   2890.000000
# 50%     2.000000   5304.000000
# 75%     7.000000   8454.000000
# max    67.000000  61426.000000

# %%
#find the duplicates
meatProd.duplicated().sum()
# Out:
# 0

# %%
#find the null values
meatProd.isnull().sum()
# Out:
# Province      0
# District      0
# Buff          0
# Mutton        0
# Chevon        0
# Pork          0
# Chicken       0
# Duck          0
# Total Meat    0
# dtype: int64

# %% [markdown]
# ### Egg Production

# %%
#viewing first five data
eggProd.head()
# Out:
#   Province  District  Laying Hen  Laying Duck  Hen Egg  Duck Egg  Total Egg
# 0        1   BHOJPUR       12315          931      924        74        998
# 1        1  DHANKUTA       38583         2014     3520       163       3683
# 2        1      ILAM       77531          494     7859        42       7901
# 3        1     JHAPA      265012         2724    28928       241      29170
# 4        1   KHOTANG       28552         1115     2173        90       2262

# %%
#returns the row and column count of a dataset
eggProd.shape
# Out:
# (77, 7)

# %%
#verify data quality and check missing values
eggProd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Province     77 non-null     object
#  1   District     77 non-null     object
#  2   Laying Hen   77 non-null     int64
#  3   Laying Duck  77 non-null     int64
#  4   Hen Egg      77 non-null     int64
#  5   Duck Egg     77 non-null     int64
#  6   Total Egg    77 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 4.3+ KB

# %%
#provide basis stastics attributes
eggProd.describe()
# Out:
#          Laying Hen   Laying Duck        Hen Egg     Duck Egg      Total Egg
# count  7.700000e+01     77.000000      77.000000    77.000000      77.000000
# mean   1.477144e+05   2864.051948   19163.948052   232.844156   19396.727273
# std    4.165941e+05   4690.421362   63029.440045   403.876025   63123.901244
# min    3.500000e+02      0.000000      27.000000     0.000000      27.000000
# 25%    1.632200e+04    278.000000    1303.000000    22.000000    1338.000000
# 50%    5.498300e+04   1039.000000    4730.000000    80.000000    5076.000000
# 75%    1.201890e+05   3716.000000   12073.000000   284.000000   12386.000000
# max    3.556513e+06  30517.000000  540590.000000  2801.000000  541142.000000

# %%
#find the duplicates
eggProd.duplicated().sum()
# Out:
# 0

# %%
#find the null values
eggProd.isnull().sum()
# Out:
# Province       0
# District       0
# Laying Hen     0
# Laying Duck    0
# Hen Egg        0
# Duck Egg       0
# Total Egg      0
# dtype: int64

# %% [markdown]
# ### Wool production

# %%
#viewing first five data
woolProd.head()
# Out:
#   Province  District  Sheeps No.  Sheep Wool Produced
# 0        1   BHOJPUR        6050                 4129
# 1        1  DHANKUTA         542                  367
# 2        1      ILAM         138                   90
# 3        1     JHAPA          38                   15
# 4        1   KHOTANG        6163                 4177

# %%
#returns the row and column count of a dataset
woolProd.shape
# Out:
# (77, 4)

# %%
#verify data quality and check missing values
woolProd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Province             77 non-null     object
#  1   District             77 non-null     object
#  2   Sheeps No.           77 non-null     int64
#  3   Sheep Wool Produced  77 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 2.5+ KB

# %%
#provide basis stastics attributes
woolProd.describe()
# Out:
#          Sheeps No.  Sheep Wool Produced
# count     77.000000            77.000000
# mean   10308.116883          7584.376623
# std    12765.496684         10754.136407
# min        0.000000             0.000000
# 25%     1242.000000           920.000000
# 50%     5258.000000          4086.000000
# 75%    14273.000000          9541.000000
# max    73241.000000         65973.000000

# %%
#find the duplicates
woolProd.duplicated().sum()
# Out:
# 0

# %%
#find the null values
woolProd.isnull().sum()
# Out:
# Province               0
# District               0
# Sheeps No.             0
# Sheep Wool Produced    0
# dtype: int64

# %% [markdown]
# ### YakNakChauri population

# %%
#viewing first five data
yakPopn.head()
# Out:
#   Province     District  Yak/Nak/Chauri
# 0        1      BHOJPUR             500
# 1        1        ILLAM              40
# 2        1      KHOTANG             190
# 3        1  OKHALDHUNGA             676
# 4        1    PANCHTHAR            1115

# %%
#returns the row and column count of a dataset
yakPopn.shape
# Out:
# (29, 3)

# %%
#verify data quality and check missing values
yakPopn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province        29 non-null     object
#  1   District        29 non-null     object
#  2   Yak/Nak/Chauri  29 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 824.0+ bytes

# %%
#provide basis stastics attributes
yakPopn.describe()
# Out:
#        Yak/Nak/Chauri
# count       29.000000
# mean      2255.379310
# std       2602.428007
# min         20.000000
# 25%        234.000000
# 50%       1015.000000
# 75%       3812.000000
# max       8538.000000

# %%
#find the duplicates
yakPopn.duplicated().sum()
# Out:
# 0

# %%
#find the null values
yakPopn.isnull().sum()
# Out:
# Province          0
# District          0
# Yak/Nak/Chauri    0
# dtype: int64

# %% [markdown]
# ### Rabbit population

# %%
#viewing first five data
rabbitPopn.head()
# Out:
#   Province  District  Rabbit
# 0        1   BHOJPUR      12
# 1        1  DHANKUTA     204
# 2        1      ILAM     190
# 3        1     JHAPA     401
# 4        1   KHOTANG     183

# %%
#returns the row and column count of a dataset
rabbitPopn.shape
# Out:
# (51, 3)

# %%
#verify data quality and check missing values
rabbitPopn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Province  51 non-null     object
#  1   District  51 non-null     object
#  2   Rabbit    51 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB

# %%
#provide basis stastics attributes
rabbitPopn.describe()
# Out:
#             Rabbit
# count    51.000000
# mean    873.156863
# std    1022.657858
# min      11.000000
# 25%     227.500000
# 50%     506.000000
# 75%    1184.500000
# max    5478.000000

# %%
#find the duplicates
rabbitPopn.duplicated().sum()
# Out:
# 0

# %%
#find the null values
rabbitPopn.isnull().sum()
# Out:
# Province    0
# District    0
# Rabbit      0
# dtype: int64

# %% [markdown]
# ### HorsesAsses population

# %%
#viewing first five data
horsesPopn.head()
# Out:
#   Province  District  Horses/Asses
# 0        1   Bhojpur            11
# 1        1  Dhankuta             9
# 2        1      Ilam          2227
# 3        1     Jhapa            32
# 4        1   Khotang           112

# %%
#returns the row and column count of a dataset
horsesPopn.shape
# Out:
# (65, 3)

# %%
#verify data quality and check missing values
horsesPopn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Province      65 non-null     object
#  1   District      65 non-null     object
#  2   Horses/Asses  65 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %%
#provide basis stastics attributes
horsesPopn.describe()
# Out:
#        Horses/Asses
# count     65.000000
# mean     844.061538
# std     1650.829686
# min        9.000000
# 25%       45.000000
# 50%      167.000000
# 75%      774.000000
# max     7901.000000

# %%
#find the duplicates
horsesPopn.duplicated().sum()
# Out:
# 0

# %%
#find the null values
horsesPopn.isnull().sum()
# Out:
# Province        0
# District        0
# Horses/Asses    0
# dtype: int64

# %% [markdown]
# ## Exploratory data analysis and visualization

# %% [markdown]
# ### Live stock population

# %%
# Plot the total number of each type of animal in each province
ax = livestockPopn.groupby('Province')[['Cattle', 'Buffaloes', 'Sheep', 'Goat', 'Pigs', 'Fowl', 'Duck']].sum().plot(kind='bar',width=0.6,figsize=(30,12))
plt.title('Total Number of Animals by Province')
plt.xlabel('Province')
plt.ylabel('Number of Animals')
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain', axis='y')

# Add text labels at the top of each bar
for rect in ax.patches:
    height = rect.get_height()
    ax.annotate(f'{height:,.0f}', 
                xy=(rect.get_x() + rect.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center', va='bottom', rotation=80)

plt.show()

# %%
# plt.barh(livestockPopn.Province, livestockPopn.Cattle, color = "#4CAF50", height = 0.6)

animals = ['Cattle', 'Buffaloes', 'Sheep', 'Goat', 'Pigs', 'Fowl', 'Duck']

for animal in animals:
    plt.figure(figsize=(12, 6))
    plt.barh(livestockPopn.Province, livestockPopn[animal], color="#4CAF50", height=0.6)
    plt.title(f"{animal} Population by Province")
    plt.xlabel("Population")
    plt.ylabel("Province")
    plt.show()

# %%
# Plot the number of each type of animal in each district of a particular province (here, province 1)
livestockPopn[livestockPopn['Province'] == '1'][['District', 'Cattle', 'Buffaloes', 'Sheep', 'Goat', 'Pigs', 'Fowl', 'Duck']].set_index('District').plot(kind='bar',width=0.7,figsize=(25,12))
plt.title('Number of Animals by District in Province 1')
plt.xlabel('District')
plt.ylabel('Number of Animals')
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
# Drop the totallivestock column
#livestockPopn = livestockPopn.drop('TotalLivestock', axis=1)

# Check the column names and make sure they don't have any spaces or special characters
print(livestockPopn.columns)

# Sum the animal population by type
animal_population = livestockPopn.iloc[:,2:].sum()

fig, ax = plt.subplots(figsize=(10,10))
ax.pie(animal_population.values, labels=animal_population.index, autopct='%1.1f%%')
ax.set_title('Animal Population by Type')
plt.show()
# Out:
# Index(['Province', 'District', 'Cattle', 'Buffaloes', 'Sheep', 'Goat', 'Pigs',
#        'Fowl', 'Duck'],
#       dtype='object')

# %%
# Import the necessary libraries
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

# Split the dataset into inputs (X) and output (y)
X = livestockPopn[['Sheep', 'Goat', 'Pigs', 'Fowl', 'Duck']].values
y = livestockPopn['Cattle'].values

# Create new features representing interactions between the existing variables
X_interactions = np.hstack([X, X[:, :2] * X[:, 3:]])

# Apply L2 regularization to the linear regression model
ridge = Ridge(alpha=0.1)
ridge.fit(X_interactions, y)

# Make predictions
predictions = ridge.predict(X_interactions)

# Combine actual and predicted values into a dataframe for easier comparison
results = pd.DataFrame({'Actual': y, 'Predicted': predictions})

# Print the first 10 rows
print(results.head(10))
# Calculate the R-squared score
accuracy = r2_score(y, predictions)

print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
#    Actual      Predicted
# 0   92751   92285.152615
# 1   95805  107405.513369
# 2  161288   95362.695000
# 3  273501  185630.456380
# 4   95898  101582.325767
# 5  432314  468395.164095
# 6   54531  113453.390795
# 7  105450   98870.391767
# 8  106030   95520.095091
# 9   51755   70818.587192
# Accuracy: 63.60%

# %%
# # create a list of land area values(sq.km) 
# Land_area = [1507, 892, 1703, 1606, 1591, 1855, 1074, 1241, 3480, 3312, 1257, 3646, 679, 2063, 1190, 1180, 1002, 1353, 1126, 1363, 1259, 1188, 119, 2218, 1926, 2191, 395, 1396, 385, 2426, 1121, 1546, 1544, 2491, 2542, 1784, 3610, 2017, 1692, 2246, 3573, 2297, 1043.1, 494, 1164, 1546, 1193, 2337, 2025, 2955, 1149, 1738, 634.88, 1373, 1309, 1879, 1161.13, 1360, 1502, 7889, 5655, 2230, 2531, 1741, 3535, 1213.49, 1462, 2451, 1680, 1519, 3422, 2188, 1538, 2322, 2025, 3235, 1610]

# # add the land area values as a new column to the dataframe
# livestockPopn['Land area'] = Land_area
